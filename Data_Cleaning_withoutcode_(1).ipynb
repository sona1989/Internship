# %% [markdown]
# <a href="https://colab.research.google.com/github/sona1989/Internship/blob/main/Data_Cleaning_withoutcode_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center><u>**`Data Cleaning`**</u></center>

# %% [markdown]
#  Data cleaning is a part of the process on a data science project.
#
# Data cleaning is the `process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data `within a dataset.
# <br>
# When you clean your data, all outdated or incorrect information is gone – leaving you with the highest quality information for your analysis and model building.

# %% [markdown]
# <p style='text-align: right;'> 4 points</p>

# %%
# ignore this code for now
from IPython.display import YouTubeVideo

YouTubeVideo('https://www.youtube.com/watch?v=XvNCSpIE9PE&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=4',width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=XvNCSpIE9PE&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# import pandas and numpy with alias pd and np respectively
import pandas as pd
import numpy as np

# %% [markdown]
# Create a dataframe, d1 = pd.DataFrame( {‘Temperature’ : [1, np.nan, 3, 2, 3] ,’Humidity’ : [22, np.nan, 2 , np.nan, 20 ] })

# %%
#create d1

# %%
d1 = pd.DataFrame( {'Temperature' : [1, np.nan, 3, 2, 3] ,'Humidity' : [22, np.nan, 2 , np.nan, 20 ] })
d1
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          3.0      20.0

# %% [markdown]
# print the dataframe d1

# %%
#print d1
d1
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          3.0      20.0

# %%
YouTubeVideo('https://www.youtube.com/watch?v=7Q_KoX3vAZ8&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=3',width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=7Q_KoX3vAZ8&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=3"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Find whether the given dataframe contain any missing values?

# %%
#check for null
d1.isnull()
# Out:
#    Temperature  Humidity
# 0        False     False
# 1         True      True
# 2        False     False
# 3        False      True
# 4        False     False

# %% [markdown]
# How many missing values does each column have?

# %%
#total null
d1.isnull().sum()
# Out:
# Temperature    1
# Humidity       2
# dtype: int64

# %%
YouTubeVideo('https://www.youtube.com/watch?v=C0hO3FiYxlk&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=2',width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=C0hO3FiYxlk&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## **`Dealing with missing values`**
# <br>Now, we know we have missing values, the next thing that we need to work on, is how to deal with these missing values

# %%
YouTubeVideo('https://www.youtube.com/watch?v=p-w5QbfWpHU&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=1',width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=p-w5QbfWpHU&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## **`Method 1: Delete the rows which contain missing values.`**
#  This method include dropping all the rows that have missing value in any column.

# %% [markdown]
#  <p style='text-align: right;'> 20 points</p>

# %% [markdown]
# Use a suitable method to drop all the rows having missing values and save the change in d2 variable

# %%
d2=d1.dropna()
d2
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 2          3.0       2.0
# 4          3.0      20.0

# %% [markdown]
# Print d2

# %%
#print nan
d2
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 2          3.0       2.0
# 4          3.0      20.0

# %% [markdown]
# Hey Remember : droping rows with nan is one of the method to deal with missing values. But you have to decide if you need to go for this method by checking percentage of nan present in the dataframe.
#
# If a column is having more than 60% of nan values then its better to remove such variables altogether if business permits

# %% [markdown]
# - ## **`Method 2: Replacing missing values`**
# Sometimes rather than dropping NA values, you'd rather replace them with a valid value. This value might be a single number like zero, or it might be some sort of imputation or interpolation

# %% [markdown]
# <p style='text-align: right;'> 30 points</p>

# %% [markdown]
# Impute the missing values with constant number of your choice

# %%
# The below output has imputed missing  values with 100

d1.fillna('100')
# Out:
#   Temperature Humidity
# 0         1.0     22.0
# 1         100      100
# 2         3.0      2.0
# 3         2.0      100
# 4         3.0     20.0

# %% [markdown]
# Do you think its a  good way to treat Nan values? What if such constant values are not suitable for our further analysis?
# Try to give your thoughts on this.

# %% [markdown]
# Impute the missing values with mean

# %%
#  imputing mean
d1.fillna(d1.mean())
# Out:
#    Temperature   Humidity
# 0         1.00  22.000000
# 1         2.25  14.666667
# 2         3.00   2.000000
# 3         2.00  14.666667
# 4         3.00  20.000000

# %% [markdown]
# Impute the missing values with median

# %%
#median imputing
d1.fillna(d1.median())
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          2.5      20.0
# 2          3.0       2.0
# 3          2.0      20.0
# 4          3.0      20.0

# %% [markdown]
# Replacing with the mean, mode or median approximations are a statistical approach of handling the missing values.
#
# Another Fun fact:
#
#     This is an approximation which can add variance to the data set. But the loss of the data can be negated by this method which yields better results compared to removal of rows and columns.

# %% [markdown]
# Impute Nan with forward fill

# %%
d1
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          3.0      20.0

# %%
#forward fill
d2=d1.ffill(axis=0)
d2
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          1.0      22.0
# 2          3.0       2.0
# 3          2.0       2.0
# 4          3.0      20.0

# %% [markdown]
# Impute Nan with backward fill

# %%
#backward fill
d3=d1.bfill(axis=0)
d3
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          3.0       2.0
# 2          3.0       2.0
# 3          2.0      20.0
# 4          3.0      20.0

# %% [markdown]
# Hey a fun fact here, as sweet as a cookie:
#
# - ffill/pad/bfill are good imputation method if our data is of time series. This would keep the trend unaffected for our analysis.

# %% [markdown]
# Impute nan using interpolation method

# %%
#interpolate
d4=d1.interpolate(method='linear')
d4
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          2.0      12.0
# 2          3.0       2.0
# 3          2.0      11.0
# 4          3.0      20.0

# %%
d1
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          3.0      20.0

# %% [markdown]
# You lucky champ! you got to know another amazing fact:
#  - Interpolation method by default is linear in nature. It is an imputation technique that assumes a linear relationship between data points and utilises non-missing values from adjacent data points to compute a value for a missing data point.
#
#
# You can explore other techniques involved in interplolation method, which might be usefull for your project.

# %% [markdown]
# Perform KNN imputation

# %%
# Hint: Import KNNImputer and impute it on d1. Also note: Use n_neighbors=2
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)
imputed = imputer.fit_transform(d1)
df_imputed = pd.DataFrame(imputed, columns=d1.columns)
df_imputed
# Out:
#    Temperature   Humidity
# 0         1.00  22.000000
# 1         2.25  14.666667
# 2         3.00   2.000000
# 3         2.00  12.000000
# 4         3.00  20.000000

# %% [markdown]
# Point to ponder: KNN is an algorithm that is useful for matching a point with its closest k neighbors in a multi-dimensional space.
#
# Do you think scaling is required to implement this method?. Yes you are right the answer is YES.
# Can you comment below why normalized data is required, so that we understand your logic on this.

# %% [markdown]
# It requires us to normalize our data. Otherwise, the different scales of our data will lead the KNN Imputer to generate biased replacements for the missing values.

# %% [markdown]
# ## **`Dropping Irrelevant Columns`**

# %% [markdown]
# <p style='text-align: right;'> 5 points</p>

# %% [markdown]
# Create a dataframe df = pd.DataFrame(np.random.randint(0,100,size=(100, 5)), columns=list('ABCDE'))

# %%
import numpy as np
import pandas as pd
np.random.seed(10)

df = pd.DataFrame(np.random.randint(0,100,size=(100, 5)), columns=list('ABCDE')) #define df

# %% [markdown]
# print df

# %%
#print df
df
# Out:
#      A   B   C   D   E
# 0    9  15  64  28  89
# 1   93  29   8  73   0
# 2   40  36  16  11  54
# 3   88  62  33  72  78
# 4   49  51  54  77  69
# ..  ..  ..  ..  ..  ..
# 95   3  50  59  34  21
# 96  16  18  61  54  60
# 97  21  87  83  71  16
# 98  67  38  27  96  87
# 99  98  89  16  82  19
#
# [100 rows x 5 columns]

# %% [markdown]
# Note: Since all the rows are having random numbers, your dataframe observations might be different than the output given above

# %% [markdown]
# Suppose for our analysis our project do not require column E. So you need to remove this column. update this new change using inplace parameter

# %%
#drop E
df.drop('E',axis=1,inplace= True)

# %% [markdown]
# Check if column **E** is removed by printing head of df

# %%
#df head
df.head(5)
# Out:
#     A   B   C   D
# 0   9  15  64  28
# 1  93  29   8  73
# 2  40  36  16  11
# 3  88  62  33  72
# 4  49  51  54  77

# %% [markdown]
# ### `Ensure requirements as per domain`

# %% [markdown]
# <p style='text-align: right;'> 10 points</p>

# %%
YouTubeVideo('https://www.youtube.com/watch?v=Y230Di2SSz8&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=5',width=600,height=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-2d4c2046a174> in <module>
# ----> 1 YouTubeVideo('https://www.youtube.com/watch?v=Y230Di2SSz8&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=5',width=600,height=300)
#
# NameError: name 'YouTubeVideo' is not defined

# %% [markdown]
# Shallow copy the dataframe df in variable df2 and print df2 head

# %%
df2=df.copy()

#df2 head
df2.head()
# Out:
#     A   B   C   D
# 0   9  15  64  28
# 1  93  29   8  73
# 2  40  36  16  11
# 3  88  62  33  72
# 4  49  51  54  77

# %% [markdown]
# Suppose your domain expert says to filter column B with even numbers to do correct analysis. Implement the same below and update the change in varaible df2.

# %%
df2=df[df['B'] % 2 == 0]

# %% [markdown]
# print updated head of *df2*

# %%
# df2 head
df2.head()
# Out:
#      A   B   C   D
# 2   40  36  16  11
# 3   88  62  33  72
# 6   30  30  89  12
# 9   11  28  74  88
# 10  15  18  80  71

# %% [markdown]
# ### `Creating a sensible index values`

# %% [markdown]
# Oops. The index in this dataframe doesn't make sense. please correct index in a sequential manner starting from 1. Save the updates in df2

# %%
#set proper index
df2.reset_index(inplace=True)

df2
# Out:
#     index   A   B   C   D
# 0       2  40  36  16  11
# 1       3  88  62  33  72
# 2       6  30  30  89  12
# 3       9  11  28  74  88
# 4      10  15  18  80  71
# 5      14  88  50  54  34
# 6      15  77  88  15   6
# 7      18  97  50  45  40
# 8      23  81  80  41  90
# 9      26  96  66  67  62
# 10     30  88  96  73  40
# 11     32  28  30  89  25
# 12     34  33   4  87  94
# 13     37  68  30  70  74
# 14     38   9   2  65  13
# 15     40  62  42  34  40
# 16     41  32  94  86  58
# 17     42  45  18  50  44
# 18     45   6  44   9  50
# 19     46  44  68  14   4
# 20     49  39  58  81  39
# 21     51  69  48  60  58
# 22     54   5  70  61  16
# 23     55   4  22  19  85
# 24     58  10  36   0  30
# 25     59  85  32  81  13
# 26     60  31  32  96  38
# 27     62   0  96  25  63
# 28     63   2  30  17  59
# 29     64  63  86  29  71
# 30     65  19   0   7  93
# 31     67  58  76  10  79
# 32     70   7  88  96  38
# 33     71  27  64  49  90
# 34     72  27  52  90  57
# 35     76  99  46  46  45
# 36     77  84  20  49  33
# 37     79  77  66  37  31
# 38     85  82  56  41  90
# 39     86  74   8  92  32
# 40     87  87  68  86  14
# 41     90  50  50  85  14
# 42     92   1  28  58  10
# 43     93   1  82  34  11
# 44     94  74  36   6  63
# 45     95   3  50  59  34
# 46     96  16  18  61  54
# 47     98  67  38  27  96

# %%
df2.drop('index',axis=1,inplace=True)
df2.index=df2.index+1
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      A   B   C   D
# 1   40  36  16  11
# 2   88  62  33  72
# 3   30  30  89  12
# 4   11  28  74  88
# 5   15  18  80  71
# 6   88  50  54  34
# 7   77  88  15   6
# 8   97  50  45  40
# 9   81  80  41  90
# 10  96  66  67  62
# 11  88  96  73  40
# 12  28  30  89  25
# 13  33   4  87  94
# 14  68  30  70  74
# 15   9   2  65  13
# 16  62  42  34  40
# 17  32  94  86  58
# 18  45  18  50  44
# 19   6  44   9  50
# 20  44  68  14   4
# 21  39  58  81  39
# 22  69  48  60  58
# 23   5  70  61  16
# 24   4  22  19  85
# 25  10  36   0  30
# 26  85  32  81  13
# 27  31  32  96  38
# 28   0  96  25  63
# 29   2  30  17  59
# 30  63  86  29  71
# 31  19   0   7  93
# 32  58  76  10  79
# 33   7  88  96  38
# 34  27  64  49  90
# 35  27  52  90  57
# 36  99  46  46  45
# 37  84  20  49  33
# 38  77  66  37  31
# 39  82  56  41  90
# 40  74   8  92  32
# 41  87  68  86  14
# 42  50  50  85  14
# 43   1  28  58  10
# 44   1  82  34  11
# 45  74  36   6  63
# 46   3  50  59  34
# 47  16  18  61  54
# 48  67  38  27  96

# %% [markdown]
# print df2 head again

# %%
# df2 head

df2.head()
# Out:
#     A   B   C   D
# 1  40  36  16  11
# 2  88  62  33  72
# 3  30  30  89  12
# 4  11  28  74  88
# 5  15  18  80  71

# %% [markdown]
# ## **`Renaming column names to meaningful names.`**
#
# <p style='text-align: right;'> 2 points</p>

# %% [markdown]
# Now df2 columns represents marks of the adventurous 'Anand', the brave 'Barkha', the compassionate 'Chandu' and the dashing 'Daniel'. Rename the columns with their name inplace of their first letter of their name.

# %%
#column renaming
df2.rename(columns={'A': 'Anand', 'B': 'Barkha','C': 'Chandu', 'D': 'Daniel'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# print df2 tail with updated column names

# %%
# df2 tail
df2.tail(5)
# Out:
#     Anand  Barkha  Chandu  Daniel
# 44      1      82      34      11
# 45     74      36       6      63
# 46      3      50      59      34
# 47     16      18      61      54
# 48     67      38      27      96

# %% [markdown]
# Yeah! now the data looks pretty meaningful to study

# %% [markdown]
# ## **`Treating Duplicate Data`**

# %% [markdown]
# <p style='text-align: right;'> 20 points</p>

# %% [markdown]
# Make another dataframe df3 by deep copying df2.

# %%
df3=df2.copy(deep=True)
df3
# Out:
#     Anand  Barkha  Chandu  Daniel
# 1      40      36      16      11
# 2      88      62      33      72
# 3      30      30      89      12
# 4      11      28      74      88
# 5      15      18      80      71
# 6      88      50      54      34
# 7      77      88      15       6
# 8      97      50      45      40
# 9      81      80      41      90
# 10     96      66      67      62
# 11     88      96      73      40
# 12     28      30      89      25
# 13     33       4      87      94
# 14     68      30      70      74
# 15      9       2      65      13
# 16     62      42      34      40
# 17     32      94      86      58
# 18     45      18      50      44
# 19      6      44       9      50
# 20     44      68      14       4
# 21     39      58      81      39
# 22     69      48      60      58
# 23      5      70      61      16
# 24      4      22      19      85
# 25     10      36       0      30
# 26     85      32      81      13
# 27     31      32      96      38
# 28      0      96      25      63
# 29      2      30      17      59
# 30     63      86      29      71
# 31     19       0       7      93
# 32     58      76      10      79
# 33      7      88      96      38
# 34     27      64      49      90
# 35     27      52      90      57
# 36     99      46      46      45
# 37     84      20      49      33
# 38     77      66      37      31
# 39     82      56      41      90
# 40     74       8      92      32
# 41     87      68      86      14
# 42     50      50      85      14
# 43      1      28      58      10
# 44      1      82      34      11
# 45     74      36       6      63
# 46      3      50      59      34
# 47     16      18      61      54
# 48     67      38      27      96

# %% [markdown]
# Make another column in df3 with name 'dummy' having 0 as values
# throughout the rows.

# %%
#assign dummy column full of zero value
df3['dummy']=0
df3
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy
# 1      40      36      16      11      0
# 2      88      62      33      72      0
# 3      30      30      89      12      0
# 4      11      28      74      88      0
# 5      15      18      80      71      0
# 6      88      50      54      34      0
# 7      77      88      15       6      0
# 8      97      50      45      40      0
# 9      81      80      41      90      0
# 10     96      66      67      62      0
# 11     88      96      73      40      0
# 12     28      30      89      25      0
# 13     33       4      87      94      0
# 14     68      30      70      74      0
# 15      9       2      65      13      0
# 16     62      42      34      40      0
# 17     32      94      86      58      0
# 18     45      18      50      44      0
# 19      6      44       9      50      0
# 20     44      68      14       4      0
# 21     39      58      81      39      0
# 22     69      48      60      58      0
# 23      5      70      61      16      0
# 24      4      22      19      85      0
# 25     10      36       0      30      0
# 26     85      32      81      13      0
# 27     31      32      96      38      0
# 28      0      96      25      63      0
# 29      2      30      17      59      0
# 30     63      86      29      71      0
# 31     19       0       7      93      0
# 32     58      76      10      79      0
# 33      7      88      96      38      0
# 34     27      64      49      90      0
# 35     27      52      90      57      0
# 36     99      46      46      45      0
# 37     84      20      49      33      0
# 38     77      66      37      31      0
# 39     82      56      41      90      0
# 40     74       8      92      32      0
# 41     87      68      86      14      0
# 42     50      50      85      14      0
# 43      1      28      58      10      0
# 44      1      82      34      11      0
# 45     74      36       6      63      0
# 46      3      50      59      34      0
# 47     16      18      61      54      0
# 48     67      38      27      96      0

# %%
# print head of df, df2 and df3
print(df.head())
print(df2.head())
print(df3.head())
# Out:
#     A   B   C   D
# 0   9  15  64  28
# 1  93  29   8  73
# 2  40  36  16  11
# 3  88  62  33  72
# 4  49  51  54  77
#    Anand  Barkha  Chandu  Daniel
# 1     40      36      16      11
# 2     88      62      33      72
# 3     30      30      89      12
# 4     11      28      74      88
# 5     15      18      80      71
#    Anand  Barkha  Chandu  Daniel  dummy
# 1     40      36      16      11      0
# 2     88      62      33      72      0
# 3     30      30      89      12      0
# 4     11      28      74      88      0
# 5     15      18      80      71      0

# %% [markdown]
# Hey buddy! Don't you think, there is some difference between copy operation used for creating df2 and df3.
#
# If you think Yes, Then please comment below the difference

# %%
# comment
deep copy if u change in another dataframe it will not reflect in the copy while in the shallow copy it will reflect the changes
# Out:
#   File "<ipython-input-117-3418f1fcf76d>", line 2
#     deep copy if u change in another dataframe it will not reflect in the copy while in the shallow copy it will reflect the changes
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# print tail of df3

# %%
# df3 tail
df3.tail(5)
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy
# 44      1      82      34      11      0
# 45     74      36       6      63      0
# 46      3      50      59      34      0
# 47     16      18      61      54      0
# 48     67      38      27      96      0

# %% [markdown]
# make an array name 'ListB' with values of column 'Barkha'

# %%
import numpy as np

ListB = np.array(df3['Barkha'])

# %% [markdown]
# Print ListB

# %%
#print ListB
ListB
# Out:
# array([36, 62, 30, 28, 18, 50, 88, 50, 80, 66, 96, 30,  4, 30,  2, 42, 94,
#        18, 44, 68, 58, 48, 70, 22, 36, 32, 32, 96, 30, 86,  0, 76, 88, 64,
#        52, 46, 20, 66, 56,  8, 68, 50, 28, 82, 36, 50, 18, 38])

# %% [markdown]
# Assign this array values as another column in df3 with name 'Anonymous'

# %%
#create Anonymous column

df3['Anonymus']=ListB
df3
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 1      40      36      16      11      0        36
# 2      88      62      33      72      0        62
# 3      30      30      89      12      0        30
# 4      11      28      74      88      0        28
# 5      15      18      80      71      0        18
# 6      88      50      54      34      0        50
# 7      77      88      15       6      0        88
# 8      97      50      45      40      0        50
# 9      81      80      41      90      0        80
# 10     96      66      67      62      0        66
# 11     88      96      73      40      0        96
# 12     28      30      89      25      0        30
# 13     33       4      87      94      0         4
# 14     68      30      70      74      0        30
# 15      9       2      65      13      0         2
# 16     62      42      34      40      0        42
# 17     32      94      86      58      0        94
# 18     45      18      50      44      0        18
# 19      6      44       9      50      0        44
# 20     44      68      14       4      0        68
# 21     39      58      81      39      0        58
# 22     69      48      60      58      0        48
# 23      5      70      61      16      0        70
# 24      4      22      19      85      0        22
# 25     10      36       0      30      0        36
# 26     85      32      81      13      0        32
# 27     31      32      96      38      0        32
# 28      0      96      25      63      0        96
# 29      2      30      17      59      0        30
# 30     63      86      29      71      0        86
# 31     19       0       7      93      0         0
# 32     58      76      10      79      0        76
# 33      7      88      96      38      0        88
# 34     27      64      49      90      0        64
# 35     27      52      90      57      0        52
# 36     99      46      46      45      0        46
# 37     84      20      49      33      0        20
# 38     77      66      37      31      0        66
# 39     82      56      41      90      0        56
# 40     74       8      92      32      0         8
# 41     87      68      86      14      0        68
# 42     50      50      85      14      0        50
# 43      1      28      58      10      0        28
# 44      1      82      34      11      0        82
# 45     74      36       6      63      0        36
# 46      3      50      59      34      0        50
# 47     16      18      61      54      0        18
# 48     67      38      27      96      0        38

# %% [markdown]
# Create a dataframe 'ListA' with values of row index 3, 10 and 40

# %%
ListA=df3.iloc[[3,10,40]]
ListA.index=ListA.index-1
ListA
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 3      11      28      74      88      0        28
# 10     88      96      73      40      0        96
# 40     87      68      86      14      0        68

# %% [markdown]
# print ListA

# %%
# print ListA
ListA
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 3      11      28      74      88      0        28
# 10     88      96      73      40      0        96
# 40     87      68      86      14      0        68

# %% [markdown]
# Concat ListA to df3 ignoring the index values of ListA so that we can maintain the sequential index value thoughout the dataframe.

# %%
#frames=[df3,ListA]
#df3=pd.concat(frames)
#df3=pd.concat([df3,ListA])
#df3
df3 = pd.concat([df3,ListA], ignore_index = True, axis = 0)
df3
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 0      40      36      16      11      0        36
# 1      88      62      33      72      0        62
# 2      30      30      89      12      0        30
# 3      11      28      74      88      0        28
# 4      15      18      80      71      0        18
# 5      88      50      54      34      0        50
# 6      77      88      15       6      0        88
# 7      97      50      45      40      0        50
# 8      81      80      41      90      0        80
# 9      96      66      67      62      0        66
# 10     88      96      73      40      0        96
# 11     28      30      89      25      0        30
# 12     33       4      87      94      0         4
# 13     68      30      70      74      0        30
# 14      9       2      65      13      0         2
# 15     62      42      34      40      0        42
# 16     32      94      86      58      0        94
# 17     45      18      50      44      0        18
# 18      6      44       9      50      0        44
# 19     44      68      14       4      0        68
# 20     39      58      81      39      0        58
# 21     69      48      60      58      0        48
# 22      5      70      61      16      0        70
# 23      4      22      19      85      0        22
# 24     10      36       0      30      0        36
# 25     85      32      81      13      0        32
# 26     31      32      96      38      0        32
# 27      0      96      25      63      0        96
# 28      2      30      17      59      0        30
# 29     63      86      29      71      0        86
# 30     19       0       7      93      0         0
# 31     58      76      10      79      0        76
# 32      7      88      96      38      0        88
# 33     27      64      49      90      0        64
# 34     27      52      90      57      0        52
# 35     99      46      46      45      0        46
# 36     84      20      49      33      0        20
# 37     77      66      37      31      0        66
# 38     82      56      41      90      0        56
# 39     74       8      92      32      0         8
# 40     87      68      86      14      0        68
# 41     50      50      85      14      0        50
# 42      1      28      58      10      0        28
# 43      1      82      34      11      0        82
# 44     74      36       6      63      0        36
# 45      3      50      59      34      0        50
# 46     16      18      61      54      0        18
# 47     67      38      27      96      0        38
# 48     11      28      74      88      0        28
# 49     88      96      73      40      0        96
# 50     87      68      86      14      0        68

# %% [markdown]
# print head of df3

# %%
# df3 head
df3.head()
# Out:
#    Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 0     40      36      16      11      0        36
# 1     88      62      33      72      0        62
# 2     30      30      89      12      0        30
# 3     11      28      74      88      0        28
# 4     15      18      80      71      0        18

# %%
df3
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 0      40      36      16      11      0        36
# 1      88      62      33      72      0        62
# 2      30      30      89      12      0        30
# 3      11      28      74      88      0        28
# 4      15      18      80      71      0        18
# 5      88      50      54      34      0        50
# 6      77      88      15       6      0        88
# 7      97      50      45      40      0        50
# 8      81      80      41      90      0        80
# 9      96      66      67      62      0        66
# 10     88      96      73      40      0        96
# 11     28      30      89      25      0        30
# 12     33       4      87      94      0         4
# 13     68      30      70      74      0        30
# 14      9       2      65      13      0         2
# 15     62      42      34      40      0        42
# 16     32      94      86      58      0        94
# 17     45      18      50      44      0        18
# 18      6      44       9      50      0        44
# 19     44      68      14       4      0        68
# 20     39      58      81      39      0        58
# 21     69      48      60      58      0        48
# 22      5      70      61      16      0        70
# 23      4      22      19      85      0        22
# 24     10      36       0      30      0        36
# 25     85      32      81      13      0        32
# 26     31      32      96      38      0        32
# 27      0      96      25      63      0        96
# 28      2      30      17      59      0        30
# 29     63      86      29      71      0        86
# 30     19       0       7      93      0         0
# 31     58      76      10      79      0        76
# 32      7      88      96      38      0        88
# 33     27      64      49      90      0        64
# 34     27      52      90      57      0        52
# 35     99      46      46      45      0        46
# 36     84      20      49      33      0        20
# 37     77      66      37      31      0        66
# 38     82      56      41      90      0        56
# 39     74       8      92      32      0         8
# 40     87      68      86      14      0        68
# 41     50      50      85      14      0        50
# 42      1      28      58      10      0        28
# 43      1      82      34      11      0        82
# 44     74      36       6      63      0        36
# 45      3      50      59      34      0        50
# 46     16      18      61      54      0        18
# 47     67      38      27      96      0        38
# 48     11      28      74      88      0        28
# 49     88      96      73      40      0        96
# 50     87      68      86      14      0        68

# %% [markdown]
# Check if there is any duplicate rows present in the dataframe df3

# %%
#check duplicate
duplicate = df3[df3.duplicated()]
duplicate
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 48     11      28      74      88      0        28
# 49     88      96      73      40      0        96
# 50     87      68      86      14      0        68

# %% [markdown]
# By above output it seems we do have duplicated rows in our dataset

# %% [markdown]
# Drop duplicated rows using pandas function keeping first values of such duplicated observations

# %%
#drop duplicate
df3.drop_duplicates( keep='first',inplace=True)
df3
# Out:
#     Anand  Barkha  Chandu  Daniel  dummy  Anonymus
# 0      40      36      16      11      0        36
# 1      88      62      33      72      0        62
# 2      30      30      89      12      0        30
# 3      11      28      74      88      0        28
# 4      15      18      80      71      0        18
# 5      88      50      54      34      0        50
# 6      77      88      15       6      0        88
# 7      97      50      45      40      0        50
# 8      81      80      41      90      0        80
# 9      96      66      67      62      0        66
# 10     88      96      73      40      0        96
# 11     28      30      89      25      0        30
# 12     33       4      87      94      0         4
# 13     68      30      70      74      0        30
# 14      9       2      65      13      0         2
# 15     62      42      34      40      0        42
# 16     32      94      86      58      0        94
# 17     45      18      50      44      0        18
# 18      6      44       9      50      0        44
# 19     44      68      14       4      0        68
# 20     39      58      81      39      0        58
# 21     69      48      60      58      0        48
# 22      5      70      61      16      0        70
# 23      4      22      19      85      0        22
# 24     10      36       0      30      0        36
# 25     85      32      81      13      0        32
# 26     31      32      96      38      0        32
# 27      0      96      25      63      0        96
# 28      2      30      17      59      0        30
# 29     63      86      29      71      0        86
# 30     19       0       7      93      0         0
# 31     58      76      10      79      0        76
# 32      7      88      96      38      0        88
# 33     27      64      49      90      0        64
# 34     27      52      90      57      0        52
# 35     99      46      46      45      0        46
# 36     84      20      49      33      0        20
# 37     77      66      37      31      0        66
# 38     82      56      41      90      0        56
# 39     74       8      92      32      0         8
# 40     87      68      86      14      0        68
# 41     50      50      85      14      0        50
# 42      1      28      58      10      0        28
# 43      1      82      34      11      0        82
# 44     74      36       6      63      0        36
# 45      3      50      59      34      0        50
# 46     16      18      61      54      0        18
# 47     67      38      27      96      0        38

# %% [markdown]
# Check again if we have any duplicate row values present

# %%
#check duplicate
duplicate = df3[df3.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Anand, Barkha, Chandu, Daniel, dummy, Anonymus]
# Index: []

# %%
def getDuplicateColumns(df3):
    '''
    Get a list of duplicate columns.
    It will iterate over all the columns in dataframe and find the columns whose contents are duplicate.
    :param df: Dataframe object
    :return: List of columns whose contents are duplicates.
    '''
    duplicateColumnNames = set()
    # Iterate over all the columns in dataframe
    for x in range(df3.shape[1]):
        # Select column at xth index.
        col = df3.iloc[:, x]
        # Iterate over all the columns in DataFrame from (x+1)th index till end
        for y in range(x + 1, df3.shape[1]):
            # Select column at yth index.
            otherCol = df3.iloc[:, y]
            # Check if two columns at x 7 y index are equal
            if col.equals(otherCol):
                duplicateColumnNames.add(df3.columns.values[y])
    return list(duplicateColumnNames)

    # Get list of duplicate columns
duplicateColumnNames = getDuplicateColumns(df3)
print('Duplicate Columns are as follows')
for col in duplicateColumnNames:
    print('Column name : ', col)
# Out:
# Duplicate Columns are as follows
# Column name :  Anonymus

# %% [markdown]
# Yipeee!! Did you notice the dataframe is free from any duplicate rows now.

# %% [markdown]
# Drop any duplicate columns present in the dataframe df

# %%
#df3=#
# Delete duplicate columns
df3 = df3.drop(columns=getDuplicateColumns(df3))
print("Modified Dataframe", df3, sep='\n')

#print df3
df3
# Out:
# Modified Dataframe
#     Anand  Barkha  Chandu  Daniel  dummy
# 0      40      36      16      11      0
# 1      88      62      33      72      0
# 2      30      30      89      12      0
# 3      11      28      74      88      0
# 4      15      18      80      71      0
# 5      88      50      54      34      0
# 6      77      88      15       6      0
# 7      97      50      45      40      0
# 8      81      80      41      90      0
# 9      96      66      67      62      0
# 10     88      96      73      40      0
# 11     28      30      89      25      0
# 12     33       4      87      94      0
# 13     68      30      70      74      0
# 14      9       2      65      13      0
# 15     62      42      34      40      0
# 16     32      94      86      58      0
# 17     45      18      50      44      0
# 18      6      44       9      50      0
# 19     44      68      14       4      0
# 20     39      58      81      39      0
# 21     69      48      60      58      0
# 22      5      70      61      16      0
# 23      4      22      19      85      0
# 24     10      36       0      30      0
# 25     85      32      81      13      0
# 26     31      32      96      38      0
# 27      0      96      25      63      0
# 28      2      30      17      59      0
# 29     63      86      29      71      0
# 30     19       0       7      93      0
# 31     58      76      10      79      0
# 32      7      88      96      38      0
# 33     27      64      49      90      0
# 34     27      52      90      57      0
# 35     99      46      46      45      0
# 36     84      20      49      33      0
# 37     77      66      37      31      0
# 38     82      56      41      90      0
# 39     74       8      92      32      0
# 40     87      68      86      14      0
# 41     50      50      85      14      0
# 42      1      28      58      10      0
# 43      1      82      34      11      0
# 44     74      36       6      63      0
# 45      3      50      59      34      0
# 46     16      18      61      54      0
# 47     67      38      27      96      0
#     Anand  Barkha  Chandu  Daniel  dummy
# 0      40      36      16      11      0
# 1      88      62      33      72      0
# 2      30      30      89      12      0
# 3      11      28      74      88      0
# 4      15      18      80      71      0
# 5      88      50      54      34      0
# 6      77      88      15       6      0
# 7      97      50      45      40      0
# 8      81      80      41      90      0
# 9      96      66      67      62      0
# 10     88      96      73      40      0
# 11     28      30      89      25      0
# 12     33       4      87      94      0
# 13     68      30      70      74      0
# 14      9       2      65      13      0
# 15     62      42      34      40      0
# 16     32      94      86      58      0
# 17     45      18      50      44      0
# 18      6      44       9      50      0
# 19     44      68      14       4      0
# 20     39      58      81      39      0
# 21     69      48      60      58      0
# 22      5      70      61      16      0
# 23      4      22      19      85      0
# 24     10      36       0      30      0
# 25     85      32      81      13      0
# 26     31      32      96      38      0
# 27      0      96      25      63      0
# 28      2      30      17      59      0
# 29     63      86      29      71      0
# 30     19       0       7      93      0
# 31     58      76      10      79      0
# 32      7      88      96      38      0
# 33     27      64      49      90      0
# 34     27      52      90      57      0
# 35     99      46      46      45      0
# 36     84      20      49      33      0
# 37     77      66      37      31      0
# 38     82      56      41      90      0
# 39     74       8      92      32      0
# 40     87      68      86      14      0
# 41     50      50      85      14      0
# 42      1      28      58      10      0
# 43      1      82      34      11      0
# 44     74      36       6      63      0
# 45      3      50      59      34      0
# 46     16      18      61      54      0
# 47     67      38      27      96      0

# %% [markdown]
#  you notice which Column is dropped?
# I am sure you noticed it.
# Name that column below

# %%
#Column:__Anonymous_________

# %% [markdown]
# ### `Treating constant column values`
#
# <p style='text-align: right;'> 2 points</p>

# %% [markdown]
# Check unique values in each columns

# %%
# df3 unique value
#df3.unique('Anand','Barkha','Chandu','Daniel','dummy')
print('Anand unique values:-',df3.Anand.unique())
print('Barkha unique values:-',df3.Barkha.unique())
print('Chandu unique values:-',df3.Chandu.unique())
print('Daniel unique values:-',df3.Daniel.unique())
print('dummy unique values:-',df3.dummy.unique())
# Out:
# Anand unique values:- [40 88 30 11 15 77 97 81 96 28 33 68  9 62 32 45  6 44 39 69  5  4 10 85
#  31  0  2 63 19 58  7 27 99 84 82 74 87 50  1  3 16 67]
# Barkha unique values:- [36 62 30 28 18 50 88 80 66 96  4  2 42 94 44 68 58 48 70 22 32 86  0 76
#  64 52 46 20 56  8 82 38]
# Chandu unique values:- [16 33 89 74 80 54 15 45 41 67 73 87 70 65 34 86 50  9 14 81 60 61 19  0
#  96 25 17 29  7 10 49 90 46 37 92 85 58  6 59 27]
# Daniel unique values:- [11 72 12 88 71 34  6 40 90 62 25 94 74 13 58 44 50  4 39 16 85 30 38 63
#  59 93 79 57 45 33 31 32 14 10 54 96]
# dummy unique values:- [0]

# %% [markdown]
# By above output which column has only 1 value as unique throught the rows?
# Yeah! you are right, its dummy column.
# So lets drop it

# %%
#count of unique value
print('Anand unique values count:-',df3.Anand.nunique())
print('Barkha unique values count:-',df3.Barkha.nunique())
print('Chandu unique values count:-',df3.Chandu.nunique())
print('Daniel unique values count:-',df3.Daniel.nunique())
print('dummy unique values count:-',df3.dummy.nunique())
# Out:
# Anand unique values count:- 42
# Barkha unique values count:- 32
# Chandu unique values count:- 40
# Daniel unique values count:- 36
# dummy unique values count:- 1

# %% [markdown]
# Drop dummy column as it has constant values which will not give us any information and save the changes to df3 using inplace parameter

# %%
# drop dummy
df3.drop('dummy',axis=1,inplace=True)

# %% [markdown]
# print final obtained dataframe df3

# %%
# print df3
df3
# Out:
#     Anand  Barkha  Chandu  Daniel
# 0      40      36      16      11
# 1      88      62      33      72
# 2      30      30      89      12
# 3      11      28      74      88
# 4      15      18      80      71
# 5      88      50      54      34
# 6      77      88      15       6
# 7      97      50      45      40
# 8      81      80      41      90
# 9      96      66      67      62
# 10     88      96      73      40
# 11     28      30      89      25
# 12     33       4      87      94
# 13     68      30      70      74
# 14      9       2      65      13
# 15     62      42      34      40
# 16     32      94      86      58
# 17     45      18      50      44
# 18      6      44       9      50
# 19     44      68      14       4
# 20     39      58      81      39
# 21     69      48      60      58
# 22      5      70      61      16
# 23      4      22      19      85
# 24     10      36       0      30
# 25     85      32      81      13
# 26     31      32      96      38
# 27      0      96      25      63
# 28      2      30      17      59
# 29     63      86      29      71
# 30     19       0       7      93
# 31     58      76      10      79
# 32      7      88      96      38
# 33     27      64      49      90
# 34     27      52      90      57
# 35     99      46      46      45
# 36     84      20      49      33
# 37     77      66      37      31
# 38     82      56      41      90
# 39     74       8      92      32
# 40     87      68      86      14
# 41     50      50      85      14
# 42      1      28      58      10
# 43      1      82      34      11
# 44     74      36       6      63
# 45      3      50      59      34
# 46     16      18      61      54
# 47     67      38      27      96

# %% [markdown]
# ### `Iterating dataframes`
# <p style='text-align: right;'> 25 points </p>
#
#
# Let's look at three main ways to iterate over DataFrames.
#
# 1. iteritems()
# 2. iterrows()
# 3. itertuples()
#
# We will also see time taken by these methods to print our dataframe.
#
# **1. Iterating DataFrames with iteritems()**
#
# Lets iterate over rows of df3 uisng iteritems.

# %%
YouTubeVideo('https://www.youtube.com/watch?v=rl3Nk-IxXV4&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=6',width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=rl3Nk-IxXV4&list=PLsR_0x6BuM-F4Z72h5D1bjWEASL0_JlrF&index=6"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import time
start = time.time()

#Use iteritems to iterate
for column_name,col_data in df3.iteritems():
  print(column_name,'\n',col_data,'\n','****'*10)

print('Time taken(sec): ',(time.time()-start)*1000)
# Out:
# Anand
#  0     40
# 1     88
# 2     30
# 3     11
# 4     15
# 5     88
# 6     77
# 7     97
# 8     81
# 9     96
# 10    88
# 11    28
# 12    33
# 13    68
# 14     9
# 15    62
# 16    32
# 17    45
# 18     6
# 19    44
# 20    39
# 21    69
# 22     5
# 23     4
# 24    10
# 25    85
# 26    31
# 27     0
# 28     2
# 29    63
# 30    19
# 31    58
# 32     7
# 33    27
# 34    27
# 35    99
# 36    84
# 37    77
# 38    82
# 39    74
# 40    87
# 41    50
# 42     1
# 43     1
# 44    74
# 45     3
# 46    16
# 47    67
# Name: Anand, dtype: int64
#  ****************************************
# Barkha
#  0     36
# 1     62
# 2     30
# 3     28
# 4     18
# 5     50
# 6     88
# 7     50
# 8     80
# 9     66
# 10    96
# 11    30
# 12     4
# 13    30
# 14     2
# 15    42
# 16    94
# 17    18
# 18    44
# 19    68
# 20    58
# 21    48
# 22    70
# 23    22
# 24    36
# 25    32
# 26    32
# 27    96
# 28    30
# 29    86
# 30     0
# 31    76
# 32    88
# 33    64
# 34    52
# 35    46
# 36    20
# 37    66
# 38    56
# 39     8
# 40    68
# 41    50
# 42    28
# 43    82
# 44    36
# 45    50
# 46    18
# 47    38
# Name: Barkha, dtype: int64
#  ****************************************
# Chandu
#  0     16
# 1     33
# 2     89
# 3     74
# 4     80
# 5     54
# 6     15
# 7     45
# 8     41
# 9     67
# 10    73
# 11    89
# 12    87
# 13    70
# 14    65
# 15    34
# 16    86
# 17    50
# 18     9
# 19    14
# 20    81
# 21    60
# 22    61
# 23    19
# 24     0
# 25    81
# 26    96
# 27    25
# 28    17
# 29    29
# 30     7
# 31    10
# 32    96
# 33    49
# 34    90
# 35    46
# 36    49
# 37    37
# 38    41
# 39    92
# 40    86
# 41    85
# 42    58
# 43    34
# 44     6
# 45    59
# 46    61
# 47    27
# Name: Chandu, dtype: int64
#  ****************************************
# Daniel
#  0     11
# 1     72
# 2     12
# 3     88
# 4     71
# 5     34
# 6      6
# 7     40
# 8     90
# 9     62
# 10    40
# 11    25
# 12    94
# 13    74
# 14    13
# 15    40
# 16    58
# 17    44
# 18    50
# 19     4
# 20    39
# 21    58
# 22    16
# 23    85
# 24    30
# 25    13
# 26    38
# 27    63
# 28    59
# 29    71
# 30    93
# 31    79
# 32    38
# 33    90
# 34    57
# 35    45
# 36    33
# 37    31
# 38    90
# 39    32
# 40    14
# 41    14
# 42    10
# 43    11
# 44    63
# 45    34
# 46    54
# 47    96
# Name: Daniel, dtype: int64
#  ****************************************
# Time taken(sec):  17.07768440246582

# %% [markdown]
# Did you notice buddy how iteritems are iterating over df3.
#
# Along with ways each iterating function works, also keep tallying the time taken for all other lopps too!. This will be fun, lets check iterrows()
#
# **2. Iterating DataFrames with iterrows()**

# %%
import time
start = time.time()
#Use iterrows to iterate
for index_of_row, data_row in df3.iterrows():
  print(index_of_row,'\n',data_row,'\n','****'*10)

print('Time taken(sec): ',(time.time()-start)*1000)
# Out:
# 0
#  Anand     40
# Barkha    36
# Chandu    16
# Daniel    11
# Name: 0, dtype: int64
#  ****************************************
# 1
#  Anand     88
# Barkha    62
# Chandu    33
# Daniel    72
# Name: 1, dtype: int64
#  ****************************************
# 2
#  Anand     30
# Barkha    30
# Chandu    89
# Daniel    12
# Name: 2, dtype: int64
#  ****************************************
# 3
#  Anand     11
# Barkha    28
# Chandu    74
# Daniel    88
# Name: 3, dtype: int64
#  ****************************************
# 4
#  Anand     15
# Barkha    18
# Chandu    80
# Daniel    71
# Name: 4, dtype: int64
#  ****************************************
# 5
#  Anand     88
# Barkha    50
# Chandu    54
# Daniel    34
# Name: 5, dtype: int64
#  ****************************************
# 6
#  Anand     77
# Barkha    88
# Chandu    15
# Daniel     6
# Name: 6, dtype: int64
#  ****************************************
# 7
#  Anand     97
# Barkha    50
# Chandu    45
# Daniel    40
# Name: 7, dtype: int64
#  ****************************************
# 8
#  Anand     81
# Barkha    80
# Chandu    41
# Daniel    90
# Name: 8, dtype: int64
#  ****************************************
# 9
#  Anand     96
# Barkha    66
# Chandu    67
# Daniel    62
# Name: 9, dtype: int64
#  ****************************************
# 10
#  Anand     88
# Barkha    96
# Chandu    73
# Daniel    40
# Name: 10, dtype: int64
#  ****************************************
# 11
#  Anand     28
# Barkha    30
# Chandu    89
# Daniel    25
# Name: 11, dtype: int64
#  ****************************************
# 12
#  Anand     33
# Barkha     4
# Chandu    87
# Daniel    94
# Name: 12, dtype: int64
#  ****************************************
# 13
#  Anand     68
# Barkha    30
# Chandu    70
# Daniel    74
# Name: 13, dtype: int64
#  ****************************************
# 14
#  Anand      9
# Barkha     2
# Chandu    65
# Daniel    13
# Name: 14, dtype: int64
#  ****************************************
# 15
#  Anand     62
# Barkha    42
# Chandu    34
# Daniel    40
# Name: 15, dtype: int64
#  ****************************************
# 16
#  Anand     32
# Barkha    94
# Chandu    86
# Daniel    58
# Name: 16, dtype: int64
#  ****************************************
# 17
#  Anand     45
# Barkha    18
# Chandu    50
# Daniel    44
# Name: 17, dtype: int64
#  ****************************************
# 18
#  Anand      6
# Barkha    44
# Chandu     9
# Daniel    50
# Name: 18, dtype: int64
#  ****************************************
# 19
#  Anand     44
# Barkha    68
# Chandu    14
# Daniel     4
# Name: 19, dtype: int64
#  ****************************************
# 20
#  Anand     39
# Barkha    58
# Chandu    81
# Daniel    39
# Name: 20, dtype: int64
#  ****************************************
# 21
#  Anand     69
# Barkha    48
# Chandu    60
# Daniel    58
# Name: 21, dtype: int64
#  ****************************************
# 22
#  Anand      5
# Barkha    70
# Chandu    61
# Daniel    16
# Name: 22, dtype: int64
#  ****************************************
# 23
#  Anand      4
# Barkha    22
# Chandu    19
# Daniel    85
# Name: 23, dtype: int64
#  ****************************************
# 24
#  Anand     10
# Barkha    36
# Chandu     0
# Daniel    30
# Name: 24, dtype: int64
#  ****************************************
# 25
#  Anand     85
# Barkha    32
# Chandu    81
# Daniel    13
# Name: 25, dtype: int64
#  ****************************************
# 26
#  Anand     31
# Barkha    32
# Chandu    96
# Daniel    38
# Name: 26, dtype: int64
#  ****************************************
# 27
#  Anand      0
# Barkha    96
# Chandu    25
# Daniel    63
# Name: 27, dtype: int64
#  ****************************************
# 28
#  Anand      2
# Barkha    30
# Chandu    17
# Daniel    59
# Name: 28, dtype: int64
#  ****************************************
# 29
#  Anand     63
# Barkha    86
# Chandu    29
# Daniel    71
# Name: 29, dtype: int64
#  ****************************************
# 30
#  Anand     19
# Barkha     0
# Chandu     7
# Daniel    93
# Name: 30, dtype: int64
#  ****************************************
# 31
#  Anand     58
# Barkha    76
# Chandu    10
# Daniel    79
# Name: 31, dtype: int64
#  ****************************************
# 32
#  Anand      7
# Barkha    88
# Chandu    96
# Daniel    38
# Name: 32, dtype: int64
#  ****************************************
# 33
#  Anand     27
# Barkha    64
# Chandu    49
# Daniel    90
# Name: 33, dtype: int64
#  ****************************************
# 34
#  Anand     27
# Barkha    52
# Chandu    90
# Daniel    57
# Name: 34, dtype: int64
#  ****************************************
# 35
#  Anand     99
# Barkha    46
# Chandu    46
# Daniel    45
# Name: 35, dtype: int64
#  ****************************************
# 36
#  Anand     84
# Barkha    20
# Chandu    49
# Daniel    33
# Name: 36, dtype: int64
#  ****************************************
# 37
#  Anand     77
# Barkha    66
# Chandu    37
# Daniel    31
# Name: 37, dtype: int64
#  ****************************************
# 38
#  Anand     82
# Barkha    56
# Chandu    41
# Daniel    90
# Name: 38, dtype: int64
#  ****************************************
# 39
#  Anand     74
# Barkha     8
# Chandu    92
# Daniel    32
# Name: 39, dtype: int64
#  ****************************************
# 40
#  Anand     87
# Barkha    68
# Chandu    86
# Daniel    14
# Name: 40, dtype: int64
#  ****************************************
# 41
#  Anand     50
# Barkha    50
# Chandu    85
# Daniel    14
# Name: 41, dtype: int64
#  ****************************************
# 42
#  Anand      1
# Barkha    28
# Chandu    58
# Daniel    10
# Name: 42, dtype: int64
#  ****************************************
# 43
#  Anand      1
# Barkha    82
# Chandu    34
# Daniel    11
# Name: 43, dtype: int64
#  ****************************************
# 44
#  Anand     74
# Barkha    36
# Chandu     6
# Daniel    63
# Name: 44, dtype: int64
#  ****************************************
# 45
#  Anand      3
# Barkha    50
# Chandu    59
# Daniel    34
# Name: 45, dtype: int64
#  ****************************************
# 46
#  Anand     16
# Barkha    18
# Chandu    61
# Daniel    54
# Name: 46, dtype: int64
#  ****************************************
# 47
#  Anand     67
# Barkha    38
# Chandu    27
# Daniel    96
# Name: 47, dtype: int64
#  ****************************************
# Time taken(sec):  76.93743705749512

# %% [markdown]
# **3. Iterating DataFrames with itertuples()**

# %%
#iterate df3 using itertuples
import time
start = time.time()

#Use itertuples to iterate
for i in df3.itertuples():
  print(i)

print('Time taken(sec): ',(time.time()-start)*1000)
# Out:
# Pandas(Index=0, Anand=40, Barkha=36, Chandu=16, Daniel=11)
# Pandas(Index=1, Anand=88, Barkha=62, Chandu=33, Daniel=72)
# Pandas(Index=2, Anand=30, Barkha=30, Chandu=89, Daniel=12)
# Pandas(Index=3, Anand=11, Barkha=28, Chandu=74, Daniel=88)
# Pandas(Index=4, Anand=15, Barkha=18, Chandu=80, Daniel=71)
# Pandas(Index=5, Anand=88, Barkha=50, Chandu=54, Daniel=34)
# Pandas(Index=6, Anand=77, Barkha=88, Chandu=15, Daniel=6)
# Pandas(Index=7, Anand=97, Barkha=50, Chandu=45, Daniel=40)
# Pandas(Index=8, Anand=81, Barkha=80, Chandu=41, Daniel=90)
# Pandas(Index=9, Anand=96, Barkha=66, Chandu=67, Daniel=62)
# Pandas(Index=10, Anand=88, Barkha=96, Chandu=73, Daniel=40)
# Pandas(Index=11, Anand=28, Barkha=30, Chandu=89, Daniel=25)
# Pandas(Index=12, Anand=33, Barkha=4, Chandu=87, Daniel=94)
# Pandas(Index=13, Anand=68, Barkha=30, Chandu=70, Daniel=74)
# Pandas(Index=14, Anand=9, Barkha=2, Chandu=65, Daniel=13)
# Pandas(Index=15, Anand=62, Barkha=42, Chandu=34, Daniel=40)
# Pandas(Index=16, Anand=32, Barkha=94, Chandu=86, Daniel=58)
# Pandas(Index=17, Anand=45, Barkha=18, Chandu=50, Daniel=44)
# Pandas(Index=18, Anand=6, Barkha=44, Chandu=9, Daniel=50)
# Pandas(Index=19, Anand=44, Barkha=68, Chandu=14, Daniel=4)
# Pandas(Index=20, Anand=39, Barkha=58, Chandu=81, Daniel=39)
# Pandas(Index=21, Anand=69, Barkha=48, Chandu=60, Daniel=58)
# Pandas(Index=22, Anand=5, Barkha=70, Chandu=61, Daniel=16)
# Pandas(Index=23, Anand=4, Barkha=22, Chandu=19, Daniel=85)
# Pandas(Index=24, Anand=10, Barkha=36, Chandu=0, Daniel=30)
# Pandas(Index=25, Anand=85, Barkha=32, Chandu=81, Daniel=13)
# Pandas(Index=26, Anand=31, Barkha=32, Chandu=96, Daniel=38)
# Pandas(Index=27, Anand=0, Barkha=96, Chandu=25, Daniel=63)
# Pandas(Index=28, Anand=2, Barkha=30, Chandu=17, Daniel=59)
# Pandas(Index=29, Anand=63, Barkha=86, Chandu=29, Daniel=71)
# Pandas(Index=30, Anand=19, Barkha=0, Chandu=7, Daniel=93)
# Pandas(Index=31, Anand=58, Barkha=76, Chandu=10, Daniel=79)
# Pandas(Index=32, Anand=7, Barkha=88, Chandu=96, Daniel=38)
# Pandas(Index=33, Anand=27, Barkha=64, Chandu=49, Daniel=90)
# Pandas(Index=34, Anand=27, Barkha=52, Chandu=90, Daniel=57)
# Pandas(Index=35, Anand=99, Barkha=46, Chandu=46, Daniel=45)
# Pandas(Index=36, Anand=84, Barkha=20, Chandu=49, Daniel=33)
# Pandas(Index=37, Anand=77, Barkha=66, Chandu=37, Daniel=31)
# Pandas(Index=38, Anand=82, Barkha=56, Chandu=41, Daniel=90)
# Pandas(Index=39, Anand=74, Barkha=8, Chandu=92, Daniel=32)
# Pandas(Index=40, Anand=87, Barkha=68, Chandu=86, Daniel=14)
# Pandas(Index=41, Anand=50, Barkha=50, Chandu=85, Daniel=14)
# Pandas(Index=42, Anand=1, Barkha=28, Chandu=58, Daniel=10)
# Pandas(Index=43, Anand=1, Barkha=82, Chandu=34, Daniel=11)
# Pandas(Index=44, Anand=74, Barkha=36, Chandu=6, Daniel=63)
# Pandas(Index=45, Anand=3, Barkha=50, Chandu=59, Daniel=34)
# Pandas(Index=46, Anand=16, Barkha=18, Chandu=61, Daniel=54)
# Pandas(Index=47, Anand=67, Barkha=38, Chandu=27, Daniel=96)
# Time taken(sec):  5.899667739868164

# %% [markdown]
# Hey buddy! so as you have seen every method works differently
#
#     iteritems(): Helps to iterate over each element of the set, column-wise.
#     iterrows(): Each element of the set, row-wise.
#     itertuple(): Each row and form a tuple out of them.
#
# But if you ask for speed. The most best perfromance is given by itertuples compared to other two iterating methods.
# So if anytime you need to save your computation time on iteration of dataframes you can go for itertuples. Was'nt it fun?:)

# %% [markdown]
# ### `Regular Expression`
# <p style='text-align: right;'> 15 points </p>
#
#
# Reference: Watch the video below
#
# Reference doc: https://www.guru99.com/python-regular-expressions-complete-tutorial.html
#
# Python has a module named re to work with RegEx
#
#
# ### **!Are you ready to try regex on dataframes?**
#
# *So here we go.!*
#
# We are gonna try out following awesome re module functions
#
# 1. findall
# 2. search
# 3. sub
# 4. split
#
# If you want you can also refer the below regular expression syntax.
#
# ![image.png](attachment:image.png)

# %%
YouTubeVideo('YXFZTKlkf-Y',width=600,height=300)

# %% [markdown]
# Hey future data scientists! we will now use regex on dataframes for data cleaning.
#
# Who doesn't know Trump?. Lets dowload this interesting dataset of Trump insult tweets :https://www.kaggle.com/ayushggarg/all-trumps-twitter-insults-20152021/download
#
# On this dataset we will learn how to use regex for data cleaning. By the way it will be also very usefull for feature engineering too!.

# %%
#load dataset
import pandas as pd

from google.colab import drive 
drive.mount('/content/gdrive')
tweet_data=pd.read_csv('gdrive/My Drive/trump.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
tweet_data.head()
# Out:
#    Unnamed: 0       date          target  \
# 0           1  10/9/2014  thomas-frieden
# 1           2  10/9/2014  thomas-frieden
# 2           3  6/16/2015     politicians
# 3           4  6/24/2015      ben-cardin
# 4           5  6/24/2015      neil-young
#
#                                               insult  \
# 0                                               fool
# 1                                               DOPE
# 2                             all talk and no action
# 3  It's politicians like Cardin that have destroy...
# 4                                    total hypocrite
#
#                                                tweet
# 0  Can you believe this fool, Dr. Thomas Frieden ...
# 1  Can you believe this fool, Dr. Thomas Frieden ...
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...
# 3  Politician @SenatorCardin didn't like that I s...
# 4  For the nonbeliever, here is a photo of @Neily...

# %%
#import re module
import re

# %% [markdown]
# Lets do some analysis using regex on this dataset
#
# Before we go ahead, do you remember apply function? because you will have to require apply function to impliment regex methods.
#
# You can refer video below:
# **1. findall()**
#
# Make another column 'year' with year in each row using regex on date column.

# %%
YouTubeVideo('T-b7TxWfrfE',width=600,height=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-979d10bb0d63> in <module>
# ----> 1 YouTubeVideo('T-b7TxWfrfE',width=600,height=300)
#
# NameError: name 'YouTubeVideo' is not defined

# %%
# create a function which takes date as parameter and applies regex on it

def convert_to_year(x):
    a = re.findall(r'\d{4}',x)[0]
    return a

#use apply function on tweet_data to use above function in order to make year column
tweet_data['year']=tweet_data['date'].apply(convert_to_year)

#print tweet_data head
tweet_data.head()
# Out:
#    Unnamed: 0       date          target  \
# 0           1  10/9/2014  thomas-frieden
# 1           2  10/9/2014  thomas-frieden
# 2           3  6/16/2015     politicians
# 3           4  6/24/2015      ben-cardin
# 4           5  6/24/2015      neil-young
#
#                                               insult  \
# 0                                               fool
# 1                                               DOPE
# 2                             all talk and no action
# 3  It's politicians like Cardin that have destroy...
# 4                                    total hypocrite
#
#                                                tweet  year
# 0  Can you believe this fool, Dr. Thomas Frieden ...  2014
# 1  Can you believe this fool, Dr. Thomas Frieden ...  2014
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...  2015
# 3  Politician @SenatorCardin didn't like that I s...  2015
# 4  For the nonbeliever, here is a photo of @Neily...  2015

# %% [markdown]
# lets filter year from 2020-2021 which was the election time in USA.
#
# **2. search**
#
# We will use regex search for this

# %%
tweet_data.info()

# %%
# create a function which takes year as parameter and applies regex on it
def year2021(x):
    y=re.search('202\d',x)      # Returns the match object
    if y:
      return x   
#use apply function on tweet_data to use above function in order to search tweets of 2020-2021
tweet_data['year']=tweet_data['year'].apply(year2021)

#tweet_data head
tweet_data.head()
# Out:
#    Unnamed: 0       date          target  \
# 0           1  10/9/2014  thomas-frieden
# 1           2  10/9/2014  thomas-frieden
# 2           3  6/16/2015     politicians
# 3           4  6/24/2015      ben-cardin
# 4           5  6/24/2015      neil-young
#
#                                               insult  \
# 0                                               fool
# 1                                               DOPE
# 2                             all talk and no action
# 3  It's politicians like Cardin that have destroy...
# 4                                    total hypocrite
#
#                                                tweet  year
# 0  Can you believe this fool, Dr. Thomas Frieden ...  None
# 1  Can you believe this fool, Dr. Thomas Frieden ...  None
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...  None
# 3  Politician @SenatorCardin didn't like that I s...  None
# 4  For the nonbeliever, here is a photo of @Neily...  None

# %% [markdown]
# You can also do the same thing using regex match function to do this which is vailable in pandas
#
# Reference: https://www.geeksforgeeks.org/python-pandas-series-str-match/

# %%
# apply pandas str.match() function
tweet_data[tweet_data['year'].str.match('^202\d')==True]
# Out:
#        Unnamed: 0      date               target  \
# 7621         7622  1/1/2020  impeachment-inquiry
# 7622         7623  1/2/2020  impeachment-inquiry
# 7623         7624  1/4/2020  impeachment-inquiry
# 7624         7625  1/6/2020          los-angeles
# 7625         7626  1/6/2020  impeachment-inquiry
# ...           ...       ...                  ...
# 10355       10356  1/6/2021        2020-election
# 10356       10357  1/6/2021        2020-election
# 10357       10358  1/6/2021        2020-election
# 10358       10359  1/6/2021        2020-election
# 10359       10360  1/6/2021           chuck-todd
#
#                                                   insult  \
# 7621             The greatest Witch Hunt in U.S. history
# 7622   Witch Hunt is sputtering badly, but still goin...
# 7623               this ridiculous Impeachment Lite Hoax
# 7624                                          poorly run
# 7625                            The great Scam continues
# ...                                                  ...
# 10355  Many States want to decertify the mistake they...
# 10356  based on irregularities and fraud, plus corrup...
# 10357  Our Election Process is worse than that of thi...
# 10358                                            a FRAUD
# 10359                        Sleepy Eyes,  Sad to watch!
#
#                                                    tweet  year
# 7621   Thank you Steve. The greatest Witch Hunt in U....  2020
# 7622   A lot of very good people were taken down by a...  2020
# 7623   As hard as I work, & as successful as our Coun...  2020
# 7624   ....If however, the city or state in question ...  2020
# 7625   “The reason they are not sending the Articles ...  2020
# ...                                                  ...   ...
# 10355  If Vice President @Mike_Pence comes through fo...  2021
# 10356  States want to correct their votes, which they...  2021
# 10357  They just happened to find 50,000 ballots late...  2021
# 10358  The States want to redo their votes. They foun...  2021
# 10359  Sleepy Eyes Chuck Todd is so happy with the fa...  2021
#
# [2739 rows x 6 columns]

# %% [markdown]
# cool right!
#
# You got some null values after applying above function. Lets drop them using dropna function. Also drop 'Unnamed: 0' column as it does not give any information.

# %%
#drop na and Unnamed: 0 column
tweet_data.dropna(inplace=True)
tweet_data.drop('Unnamed: 0',axis=1,inplace=True)
tweet_data
# Out:
#            date               target  \
# 7621   1/1/2020  impeachment-inquiry
# 7622   1/2/2020  impeachment-inquiry
# 7623   1/4/2020  impeachment-inquiry
# 7624   1/6/2020          los-angeles
# 7625   1/6/2020  impeachment-inquiry
# ...         ...                  ...
# 10355  1/6/2021        2020-election
# 10356  1/6/2021        2020-election
# 10357  1/6/2021        2020-election
# 10358  1/6/2021        2020-election
# 10359  1/6/2021           chuck-todd
#
#                                                   insult  \
# 7621             The greatest Witch Hunt in U.S. history
# 7622   Witch Hunt is sputtering badly, but still goin...
# 7623               this ridiculous Impeachment Lite Hoax
# 7624                                          poorly run
# 7625                            The great Scam continues
# ...                                                  ...
# 10355  Many States want to decertify the mistake they...
# 10356  based on irregularities and fraud, plus corrup...
# 10357  Our Election Process is worse than that of thi...
# 10358                                            a FRAUD
# 10359                        Sleepy Eyes,  Sad to watch!
#
#                                                    tweet  year
# 7621   Thank you Steve. The greatest Witch Hunt in U....  2020
# 7622   A lot of very good people were taken down by a...  2020
# 7623   As hard as I work, & as successful as our Coun...  2020
# 7624   ....If however, the city or state in question ...  2020
# 7625   “The reason they are not sending the Articles ...  2020
# ...                                                  ...   ...
# 10355  If Vice President @Mike_Pence comes through fo...  2021
# 10356  States want to correct their votes, which they...  2021
# 10357  They just happened to find 50,000 ballots late...  2021
# 10358  The States want to redo their votes. They foun...  2021
# 10359  Sleepy Eyes Chuck Todd is so happy with the fa...  2021
#
# [2739 rows x 5 columns]

# %% [markdown]
# **3. sub() Function**
#
# Now you have filtered the dataset with 2739 rows. Let's remove all @ from tweet column suing re sub() function.

# %%
# create a function which takes tweet as parameter and applies regex on it
def remove_at(x):
 
    s1=re.sub(r'@',"",x)
    return s1

#use apply function on tweet_data to use above function in order to remove @ from tweets
tweet_data['tweet']=tweet_data['tweet'].apply(remove_at)
#tweet_data head
tweet_data.head()
# Out:
#           date               target  \
# 7621  1/1/2020  impeachment-inquiry
# 7622  1/2/2020  impeachment-inquiry
# 7623  1/4/2020  impeachment-inquiry
# 7624  1/6/2020          los-angeles
# 7625  1/6/2020  impeachment-inquiry
#
#                                                  insult  \
# 7621            The greatest Witch Hunt in U.S. history
# 7622  Witch Hunt is sputtering badly, but still goin...
# 7623              this ridiculous Impeachment Lite Hoax
# 7624                                         poorly run
# 7625                           The great Scam continues
#
#                                                   tweet  year
# 7621  Thank you Steve. The greatest Witch Hunt in U....  2020
# 7622  A lot of very good people were taken down by a...  2020
# 7623  As hard as I work, & as successful as our Coun...  2020
# 7624  ....If however, the city or state in question ...  2020
# 7625  “The reason they are not sending the Articles ...  2020

# %% [markdown]
# You can also use the sub function just in one line using list comprehension. Can you try doing it below?

# %%
# sub() suing list comprehension
tweet_data['tweet']=[re.sub(r'@',"",str(x)) for x in tweet_data['tweet']]
tweet_data.head()
# Out:
#           date               target  \
# 7621  1/1/2020  impeachment-inquiry
# 7622  1/2/2020  impeachment-inquiry
# 7623  1/4/2020  impeachment-inquiry
# 7624  1/6/2020          los-angeles
# 7625  1/6/2020  impeachment-inquiry
#
#                                                  insult  \
# 7621            The greatest Witch Hunt in U.S. history
# 7622  Witch Hunt is sputtering badly, but still goin...
# 7623              this ridiculous Impeachment Lite Hoax
# 7624                                         poorly run
# 7625                           The great Scam continues
#
#                                                   tweet  year
# 7621  Thank you Steve. The greatest Witch Hunt in U....  2020
# 7622  A lot of very good people were taken down by a...  2020
# 7623  As hard as I work, & as successful as our Coun...  2020
# 7624  ....If however, the city or state in question ...  2020
# 7625  “The reason they are not sending the Articles ...  2020

# %% [markdown]
# **4. split() Function**
#
# Lets now split the column target by making another column Name which has name before hyphen("-")

# %%
# create a function which takes target as parameter and applies regex on it
def targethy(x):
  b=re.split("-",x)
  if b:
     return b[0]

#use apply function on tweet_data to use above function in order to create Name column
tweet_data['Name']=tweet_data['target'].apply(targethy)

#tweet_data head
tweet_data.head()
# Out:
#           date               target  \
# 7621  1/1/2020  impeachment-inquiry
# 7622  1/2/2020  impeachment-inquiry
# 7623  1/4/2020  impeachment-inquiry
# 7624  1/6/2020          los-angeles
# 7625  1/6/2020  impeachment-inquiry
#
#                                                  insult  \
# 7621            The greatest Witch Hunt in U.S. history
# 7622  Witch Hunt is sputtering badly, but still goin...
# 7623              this ridiculous Impeachment Lite Hoax
# 7624                                         poorly run
# 7625                           The great Scam continues
#
#                                                   tweet  year         Name
# 7621  Thank you Steve. The greatest Witch Hunt in U....  2020  impeachment
# 7622  A lot of very good people were taken down by a...  2020  impeachment
# 7623  As hard as I work, & as successful as our Coun...  2020  impeachment
# 7624  ....If however, the city or state in question ...  2020          los
# 7625  “The reason they are not sending the Articles ...  2020  impeachment

# %% [markdown]
# Now can you filter out Name which are specially targetted for trump? Lets do it below and check how many such tweets are there.

# %%
#filter Name which is euqals to trump

#tweet_data[tweet_data['Name'].str.match('trump')==True]
tweet_data[tweet_data['Name']=='trump']
# Out:
#              date         target  \
# 7859     2/9/2020   trump-russia
# 7860     2/9/2020   trump-russia
# 7861     2/9/2020   trump-russia
# 7890    2/12/2020   trump-russia
# 7891    2/12/2020   trump-russia
# ...           ...            ...
# 9658    10/7/2020   trump-russia
# 9659    10/7/2020   trump-russia
# 10091  11/22/2020   trump-russia
# 10188   12/9/2020  trump-critics
# 10258  12/18/2020   trump-russia
#
#                                                   insult  \
# 7859   THE WHOLE SCAM INVESTIGATION, THE MUELLER REPO...
# 7860   the biggest political crime in American Histor...
# 7861   THE PARTY IN POWER ILLEGALLY SPIED ON MY CAMPAIGN
# 7890                   an investigation that was illegal
# 7891                                    the Mueller Scam
# ...                                                  ...
# 9658                                        Hoax Scandal
# 9659   the biggest political crime in the history of ...
# 10091                            never ending Witch Hunt
# 10188                                          obnoxious
# 10258                                        Russia Hoax
#
#                                                    tweet  year   Name
# 7859   FBI Director Christopher Wray just admitted th...  2020  trump
# 7860   ....This is the biggest political crime in Ame...  2020  trump
# 7861   ....This is the biggest political crime in Ame...  2020  trump
# 7890   Who are the four prosecutors (Mueller people?)...  2020  trump
# 7891   Who are the four prosecutors (Mueller people?)...  2020  trump
# ...                                                  ...   ...    ...
# 9658   All Russia Hoax Scandal information was Declas...  2020  trump
# 9659   All Russia Hoax Scandal information was Declas...  2020  trump
# 10091  Thanks Mark. It’s all a continuation of the ne...  2020  trump
# 10188  Germany has consistently been used by my obnox...  2020  trump
# 10258  The Russia Hoax becomes an even bigger lie! ht...  2020  trump
#
# [65 rows x 6 columns]

# %% [markdown]
# So here you got total of 65 records which were  tweeted on Donald Trump in the span of 2020-2021.
#
# Well done buddy! You have learned how to apply regex on dataframes. Regex are mostly used for datasets which are having textual information.

# %%
#resetting index 
tweet_data.reset_index(drop=True)
# Out:
#           date               target  \
# 0     1/1/2020  impeachment-inquiry
# 1     1/2/2020  impeachment-inquiry
# 2     1/4/2020  impeachment-inquiry
# 3     1/6/2020          los-angeles
# 4     1/6/2020  impeachment-inquiry
# ...        ...                  ...
# 2734  1/6/2021        2020-election
# 2735  1/6/2021        2020-election
# 2736  1/6/2021        2020-election
# 2737  1/6/2021        2020-election
# 2738  1/6/2021           chuck-todd
#
#                                                  insult  \
# 0               The greatest Witch Hunt in U.S. history
# 1     Witch Hunt is sputtering badly, but still goin...
# 2                 this ridiculous Impeachment Lite Hoax
# 3                                            poorly run
# 4                              The great Scam continues
# ...                                                 ...
# 2734  Many States want to decertify the mistake they...
# 2735  based on irregularities and fraud, plus corrup...
# 2736  Our Election Process is worse than that of thi...
# 2737                                            a FRAUD
# 2738                        Sleepy Eyes,  Sad to watch!
#
#                                                   tweet  year         Name
# 0     Thank you Steve. The greatest Witch Hunt in U....  2020  impeachment
# 1     A lot of very good people were taken down by a...  2020  impeachment
# 2     As hard as I work, & as successful as our Coun...  2020  impeachment
# 3     ....If however, the city or state in question ...  2020          los
# 4     “The reason they are not sending the Articles ...  2020  impeachment
# ...                                                 ...   ...          ...
# 2734  If Vice President Mike_Pence comes through for...  2021         2020
# 2735  States want to correct their votes, which they...  2021         2020
# 2736  They just happened to find 50,000 ballots late...  2021         2020
# 2737  The States want to redo their votes. They foun...  2021         2020
# 2738  Sleepy Eyes Chuck Todd is so happy with the fa...  2021        chuck
#
# [2739 rows x 6 columns]

# %% [markdown]
# Good job!  Now our interesting trump insult tweet data is somewhat cleaned.

# %% [markdown]
# ---------------------------------
#
# # C'mon cheers:) you have completed the 5th milestone challenge too.
#
# --------------------------------

# %% [markdown]
# # FeedBack
# We hope you’ve enjoyed this course so far. We’re committed to help you use "AI for All" course to its full potential, so that you have a great learning experience. And that’s why we need your help in form of a feedback here.
#
# Please fill this feedback form https://docs.google.com/forms/d/e/1FAIpQLSfjBmH0yJSSA34IhSVx4h2eDMgOAeG4Dk-yHid__NMTk3Hq5g/viewform
